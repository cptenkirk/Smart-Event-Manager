# %%
print('hello')

animals = ['katze', 'hund', 'maus']
print(*animals)
""" das * sorgt dafür, dass die Liste aufgelöst wird ohne Klammern und Kommas """

for animal in animals:
    print(animal, end=" ") 
    """ end=" " sorgt dafür, dass die Ausgabe in einer Zeile bleibt """

print()  # fügt eine neue Zeile hinzu

for number in range (10):
    if number in (1,2,7):
        print("if", number, end=" ")

    else:
        print("else", number, end=" ")

print()  # fügt eine neue Zeile hinzu

""" i=1
while i<=10:
    print("i is", i, end="")
i=i-1 """
""" i=i+1 muss eingerückt sein, damit die Schleife funktioniert """

print() 

def add_1(num):
    return num + 1

result = add_1(8)
print(result)

print()

class MyClass: 
    def __init__(self): # Konstruktor, initialisiert die instanzvariable "myvar"
        self.myvar = 100 # Instanzvariable
    def myfunc(self, arg1): # arg1 ist ein Parameter der Methode myfunc, sie ist ein Eingabewert, der Methode myfunc übergeben wird
        print("arg1 =", arg1) # gibt den Wert von arg1 aus
        return self.myvar+arg1 # gibt die Summe von myvar und arg1 zurück
    
myclass = MyClass() # Instanz der Klasse MyClass erstellen
print(myclass.myfunc(20)) # Methode myfunc der Instanz aufrufen und Ergebnis drucken

print()
# Out:
# hello
# katze hund maus
# katze hund maus
# else 0 if 1 if 2 else 3 else 4 else 5 else 6 if 7 else 8 else 9
#
# 9
#
# arg1 = 20
# 120

# %%
""" %pip install matplotlib """

import matplotlib.pyplot as plt

plt.plot([0, 1, 2, 3], [4, 2, 9, 14], 'go') # zeichnung von einem 2 dimensionalen Diagramm mit grünen Punkten
plt.ylabel('y') 
plt.xlabel('x')
plt.axis([0,4,1,15])
plt.grid(True) # Gitter einfügen
plt.show()

# %%
""" Größter gemeinsamer Teiler gcd(65,143) mit euklidischer Algorithmus"""

class gcd: # Klassen definition gcd = greatest common divisor / größter gemeinsamer Teiler
    def __init__ (self, smaller, larger): # Konstruktor der Klasse gcd, initialisiert die Instanzvariablen smaller und larger
        self.smaller = smaller # Instanzvariable smaller
        self.larger = larger # Instanzvariable larger

    def gcd_greatest(smaller, larger): # Methode gcd_greatest der Klasse gcd, die den größten gemeinsamen Teiler berechnet, 2 Argumente erwartet: smaller und larger, sie implementiert den euklidischen Algorithmus
        if larger % smaller == 0: # wenn larger durch smaller ohne Rest teilbar ist
            return smaller # gibt smaller zurück als größten gemeinsamen Teiler
        else: # Rekursiver Fall. Wird ausgeführt, wenn larger nicht durch smaller ohne Rest teilbar ist
            return gcd.gcd_greatest(larger % smaller, smaller) # rekursiver Aufruf der Methode gcd_greatest mit neuen Argumenten: larger % smaller und smaller, sie wird wiederholt bis der rest null ist.
print("gcd(65,143) =", result) # gibt das Ergebnis des größten gemeinsamen Teilers von 65 und 143 aus

""" Aufruf 1: gcd_greatest(65, 143) 
143 mod 65 = 13 (Rest ungleich 0)
Ruft auf: gcd_greatest(13, 65)

Aufruf 2: gcd_greatest(13, 65)
65 \bmod 13 = 0$ (Rest gleich 0)
Gibt die kleinere Zahl (13) zurück. """
# Out:
# gcd(65,143) = 13

# %%
""" %pip install numpy """

import numpy as np

a=np.array([1,2,3,4])
print(*a)

# Erstellen eines 2 dimensionalen Arrays (eine Matrize)

b=np.array([[1,2],[3,5],[15,10],[13,12]])
print(b.shape) # gibt die Form des Arrays aus (Anzahl der Zeilen und Spalten)
print(b[2,1]) # gibt das Element in der 3. Zeile und 2. Spalte aus
print(b, end="\n")

plt.plot(b[:,0],b[:,1],'o',label='data')

""" b[:,0] bedeutet: alle Zeilen (:) der 1. Spalte (0)"""
""" b[:,1] bedeutet: alle Zeilen (:) der 2. Spalte (1)"""
# Out:
# 1 2 3 4
# (4, 2)
# 10
# [[ 1  2]
#  [ 3  5]
#  [15 10]
#  [13 12]]
